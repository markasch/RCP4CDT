# %% [markdown]
# # Ex. S2: Multi-Stage Stochastic
#
# The multi-stage stochastic scheduling problem is a straightfoward extension of the two-stage cases that we have studued previously. It provides the possibility to model a more complex decision-making process, where uncertain, exogenous inputs act on the system at each stage of its evolution.
